# %%
# !git add .
# !git commit -m "Arrays Easy Problem Completed"
# !git push
# Out:
# [main 5ba42ec] Arrays Easy Problem Completed
#  Committer: Manish Tanwar <manish@Manishs-MacBook-Air.local>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly:
#
#     git config --global user.name "Your Name"
#     git config --global user.email you@example.com
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  108 files changed, 6619 insertions(+), 22 deletions(-)
#  create mode 100644 .DS_Store
#  rename Untitled1.ipynb => .ipynb_checkpoints/Commit-checkpoint.ipynb (94%)
#  create mode 100644 .ipynb_checkpoints/Load_Problems-checkpoint.ipynb
#  delete mode 100644 .ipynb_checkpoints/Untitled1-checkpoint.ipynb
#  create mode 100644 .{filename}
#  rename Arrays/.ipynb_checkpoints/{01_Intro-checkpoint.ipynb => 00.Intro-checkpoint.ipynb} (97%)
# ...

# %%
# !git branch --unset-upstream
