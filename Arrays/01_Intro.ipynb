// %% [markdown]
// # Array

// %% [markdown]
// - An array stores items or their references at contiguous locations.
// - It offers mainly the following advantages over other data structures.
//     - **Random Access** : i-th item can be accessed in O(1) Time as we have the base address and every item or reference is of same size.
//     - **Cache Friendliness** : Since items / references are stored at contiguous locations, we get the advantage of locality of reference.
// - It is not useful in places where we have operations like insert in the middle, delete from middle and search in a unsorted data.
// - It is a fundamental and linear data structure using which we build other data structures like Stack Queue, Deque, Graph, Hash Table, etc.
// - [Read More](https://www.geeksforgeeks.org/dsa/array-data-structure-guide/)

// %% [markdown]
// ## Basic terminologies of Array
// - **Index**: In an array, elements are identified by their indexes. Array index starts from 0.
// - **Element**: Elements are items stored in an array and can be accessed by their index.
// - **Length**: The length of an array is determined by the number of elements it can contain.

// %% [markdown]
// ## Memory Representation
// - Elements are stored in contiguous memory locations.
// - ![image.png](attachment:b370f3c5-8aa6-42c0-bd61-b285d0e48feb.png)

// %% [markdown]
// ## Types
// ![image.png](attachment:70704148-4474-4d5c-889f-5d3820f84253.png)
// - Fixed Sized Arrays
//     - Once created we cannot alter or update the size of this array
// - Dynamic Sized Arrays
//     - The size of the array changes as per requirements during execution of code.
//     - The memory is mostly dynamically allocated and de-allocated in these arrays.

// %% [markdown]
// ## Operations
// 1. Array Traversal
//     - Linear(Sequential) Traversal
//     - Reverse Traversal
// 2. Insertion in Array
//     - At Beginning
//     - At End
//     - At Specific Index
// 3. Deletion
//     - First Element
//     - Last Element
//     - Specific Element (At Index i)
// 4. Searching
//     - Linear (Sequential) Search
//     - Binary Search

// %% [markdown]
// ## Advantages
// - Efficient and Fast Access (constant access time)
// - Memory Efficient
// - Versatility
// - Compatibility with hardware

// %% [markdown]
// ## Disadvantages

// %% [markdown]
// - Fixed Size
// - Memory Allocation Issue
// - Frequent Insertion and Deletion
// - Limited Data Type Support
// - Lack of flexibility

// %% [markdown]
// ## Recognizing a JS Array
// - Array.isArray()
// - instanceof

// %% [markdown]
// # Problems

// %% [markdown]
// ## Basic 01
// - [X] [01.001 Print Alternates](/lab/tree/Arrays/01.001.ipynb)
// - [X] [01.002 Leaders in an Array](/lab/tree/Arrays/01.002.ipynb)
// - [ ] [01.003 Check if an Array is Sorted](/lab/tree/Arrays/01.003.ipynb)
